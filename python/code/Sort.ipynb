# %%
#Sort
import os
import IPython.display as ipd
import librosa

input_folder = './clips_from_filtered_recordings/'

# %%
for filename in os.listdir(input_folder):
    filename = '20190611161936_026_02278_153003.m4a'
    print('filename is ', filename)
    audio_in_path = input_folder + '/' + filename
    y, sr = librosa.load(audio_in_path, sr=None) 
    print('y shape ', y.shape)
    print('sr ', sr)
    ipd.Audio(y, rate=sr) # load a NumPy array
    #from playsound import playsound
    #playsound(filename)
    break
# Out:
# filename is  20190611161936_026_02278_153003.m4a
# y shape  (22050,)
# sr  22050
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-80930e94a3a5> in <module>
#       8     #ipd.Audio(y, rate=sr) # load a NumPy array
#       9     from playsound import playsound
# ---> 10     playsound(filename)
#      11     break
#      12
#
# ~/anaconda3/envs/tim1/lib/python3.6/site-packages/playsound.py in _playsoundNix(sound, block)
#      89         from urllib import pathname2url
#      90
# ---> 91     import gi
#      92     gi.require_version('Gst', '1.0')
#      93     from gi.repository import Gst
#
# ModuleNotFoundError: No module named 'gi'

# %%
import IPython.display as ipd
#ipd.Audio('test1.wav') # load a local WAV file
ipd.Audio('./wavfiles/151837_bird_27.18.wav') # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
#input_folder = './clips_from_filtered_recordings/'
ipd.Audio('./clips_from_filtered_recordings/20190611161936_026_02278_153003.m4a') # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import IPython.display as ipd
input_folder = './clips_from_filtered_recordings/'
ipd.Audio(input_folder + '20190611161936_026_02278_153003.m4a') # load a local WAV file
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Generate a sound
import numpy as np
import IPython.display as ipd
framerate = 44100
t = np.linspace(0,5,framerate*5)
#data = np.sin(2*np.pi*220*t) + np.sin(2*np.pi*224*t)
input_folder = './clips_from_filtered_recordings/'
filename = '20190611161936_026_02278_153003.m4a'
audio_in_path = input_folder + '/' + filename
y, sr = librosa.load(audio_in_path, sr=None) 
#ipd.Audio( ,rate=framerate)
ipd.Audio( y,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os
input_folder = './clips_from_filtered_recordings/'
for filename in os.listdir(input_folder):
    #ipd.set_matplotlib_close(close=True)
    audio_in_path = input_folder + '/' + filename
    print('audio_in_path ', audio_in_path)
    y, sr = librosa.load(audio_in_path, sr=None) 
    #https://stackoverflow.com/questions/54417598/playing-audio-in-jupyter-in-a-for-loop
    #ipd.Audio( y,rate=sr)
    ipd.display(ipd.Audio(y, rate=sr))
    ipd.set_matplotlib_close(close=True)
    reply = input("Press Enter to continue...")
    print('reply ', reply)
    ipd.set_matplotlib_close(close=True)
    #ipd.set_matplotlib_close(close=True)
# Out:
# audio_in_path  ./clips_from_filtered_recordings//20190611162459_019_01719_153544.m4a
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Press Enter to continue...ss
# reply  ss
# audio_in_path  ./clips_from_filtered_recordings//20190611162633_013_01140_159480.m4a
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Press Enter to continue...ss
# reply  ss
# audio_in_path  ./clips_from_filtered_recordings//20190611163349_048_04183_159487.m4a
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
# ...
